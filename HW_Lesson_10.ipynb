# %% [markdown]
# # Neural machine translation with attention

# %%
import tensorflow as tf

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from sklearn.model_selection import train_test_split

import unicodedata
import re
import numpy as np
import os
import io
import time

# %% [markdown]
# ## Download and prepare the dataset
#
# We'll use a language dataset provided by http://www.manythings.org/anki/

# %%
# !wget http://www.manythings.org/anki/rus-eng.zip
# Out:
# --2022-08-09 10:59:20--  http://www.manythings.org/anki/rus-eng.zip
# Resolving www.manythings.org (www.manythings.org)... 173.254.30.110
# Connecting to www.manythings.org (www.manythings.org)|173.254.30.110|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14819554 (14M) [application/zip]
# Saving to: ‘rus-eng.zip’
#
# rus-eng.zip         100%[===================>]  14.13M  4.85MB/s    in 2.9s
#
# 2022-08-09 10:59:24 (4.85 MB/s) - ‘rus-eng.zip’ saved [14819554/14819554]

# %%
# !mkdir rus-eng
# !unzip rus-eng.zip -d rus-eng/
# Out:
# Archive:  rus-eng.zip
#   inflating: rus-eng/rus.txt
#   inflating: rus-eng/_about.txt

# %%
# !ls /content/rus-eng/ -lah
# Out:
# total 71M
# drwxr-xr-x 2 root root 4.0K Aug  9 10:59 .
# drwxr-xr-x 1 root root 4.0K Aug  9 10:59 ..
# -rw-r--r-- 1 root root 1.5K May  2 01:29 _about.txt
# -rw-r--r-- 1 root root  71M May  2 01:29 rus.txt

# %%
# Download the file
path_to_file = "/content/rus-eng/rus.txt"

# %%
def preprocess_sentence(w):
  w = w.lower().strip()

  # creating a space between a word and the punctuation following it
  # eg: "he is a boy." => "he is a boy ."
  # Reference:- https://stackoverflow.com/questions/3645931/python-padding-punctuation-with-white-spaces-keeping-punctuation
  w = re.sub(r"([?.!,])", r" \1 ", w)
  w = re.sub(r'[" "]+', " ", w)

  # replacing everything with space except (a-z, A-Z, ".", "?", "!", ",")
  w = re.sub(r"[^a-zA-Zа-яА-Я?.!,']+", " ", w)

  w = w.strip()

  # adding a start and an end token to the sentence
  # so that the model know when to start and stop predicting.
  w = '<start> ' + w + ' <end>'
  return w

# %%
preprocess_sentence("I can't go.")
# Out:
# "<start> i can't go . <end>"

# %%
# 1. Remove the accents
# 2. Clean the sentences
# 3. Return word pairs in the format: [ENG, RUS]
def create_dataset(path, num_examples):
  lines = io.open(path, encoding='UTF-8').read().strip().split('\n')

  word_pairs = [[preprocess_sentence(w) for w in l.split('\t')[:2]]  for l in lines[:num_examples]]

  return zip(*word_pairs)

# %%
en, ru = create_dataset(path_to_file, None)
print(en[-1])
print(ru[-1])
# Out:
# <start> doubtless there exists in this world precisely the right woman for any given man to marry and vice versa but when you consider that a human being has the opportunity of being acquainted with only a few hundred people , and out of the few hundred that there are but a dozen or less whom he knows intimately , and out of the dozen , one or two friends at most , it will easily be seen , when we remember the number of millions who inhabit this world , that probably , since the earth was created , the right man has never yet met the right woman . <end>
# <start> несомненно , для каждого мужчины в этом мире где то есть подходящая женщина , которая может стать ему женой , обратное верно и для женщин . но если учесть , что у человека может быть максимум несколько сотен знакомых , из которых лишь дюжина , а то и меньше , тех , кого он знает близко , а из этой дюжины у него один или от силы два друга , то можно легко увидеть , что с уч том миллионов живущих на земле людей , ни один подходящий мужчина , возможно , ещ не встретил подходящую женщину . <end>

# %%
def tokenize(lang):
  lang_tokenizer = tf.keras.preprocessing.text.Tokenizer(
      filters='')
  lang_tokenizer.fit_on_texts(lang)

  tensor = lang_tokenizer.texts_to_sequences(lang)

  tensor = tf.keras.preprocessing.sequence.pad_sequences(tensor,
                                                         padding='post')

  return tensor, lang_tokenizer

# %%
def load_dataset(path, num_examples=None):
  # creating cleaned input, output pairs
  targ_lang, inp_lang = create_dataset(path, num_examples)

  input_tensor, inp_lang_tokenizer = tokenize(inp_lang)
  target_tensor, targ_lang_tokenizer = tokenize(targ_lang)

  return input_tensor, target_tensor, inp_lang_tokenizer, targ_lang_tokenizer

# %% [markdown]
# ### Limit the size of the dataset to experiment faster (optional)

# %%
len(en), len(ru)
# Out:
# (444587, 444587)

# %%
# Try experimenting with the size of that dataset
num_examples = 100000
input_tensor, target_tensor, inp_lang, targ_lang = load_dataset(path_to_file, num_examples)

# Calculate max_length of the target tensors
max_length_targ, max_length_inp = target_tensor.shape[1], input_tensor.shape[1]

# %%
# Creating training and validation sets using an 80-20 split
input_tensor_train, input_tensor_val, target_tensor_train, target_tensor_val = train_test_split(input_tensor, target_tensor, test_size=0.2)

# Show length
print(len(input_tensor_train), len(target_tensor_train), len(input_tensor_val), len(target_tensor_val))
# Out:
# 80000 80000 20000 20000

# %%
def convert(lang, tensor):
  for t in tensor:
    if t!=0:
      print ("%d ----> %s" % (t, lang.index_word[t]))

# %%
print ("Input Language; index to word mapping")
convert(inp_lang, input_tensor_train[0])
print ()
print ("Target Language; index to word mapping")
convert(targ_lang, target_tensor_train[0])
# Out:
# Input Language; index to word mapping
# 1 ----> <start>
# 1769 ----> чь
# 8 ----> это
# 278 ----> место
# 5 ----> ?
# 2 ----> <end>
#
# Target Language; index to word mapping
# 1 ----> <start>
# 413 ----> whose
# 594 ----> seat
# 8 ----> is
# 19 ----> this
# 6 ----> ?
# 2 ----> <end>

# %% [markdown]
# ### Create a tf.data dataset

# %%
BUFFER_SIZE = len(input_tensor_train)
BATCH_SIZE = 64
steps_per_epoch = len(input_tensor_train)//BATCH_SIZE
embedding_dim = 256
units = 1024
vocab_inp_size = len(inp_lang.word_index)+1
vocab_tar_size = len(targ_lang.word_index)+1

dataset = tf.data.Dataset.from_tensor_slices((input_tensor_train, target_tensor_train)).shuffle(BUFFER_SIZE)
dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)

# %%
example_input_batch, example_target_batch = next(iter(dataset))
example_input_batch.shape, example_target_batch.shape
# Out:
# (TensorShape([64, 15]), TensorShape([64, 11]))

# %%
class Encoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_dim, enc_units, batch_sz):
    super(Encoder, self).__init__()
    self.batch_sz = batch_sz
    self.enc_units = enc_units
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(self.enc_units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')

  def call(self, x, hidden):
    x = self.embedding(x)
    output, state = self.gru(x, initial_state = hidden)
    return output, state

  def initialize_hidden_state(self):
    return tf.zeros((self.batch_sz, self.enc_units))

# %%
encoder = Encoder(vocab_inp_size, embedding_dim, units, BATCH_SIZE)

# sample input
sample_hidden = encoder.initialize_hidden_state()
sample_output, sample_hidden = encoder(example_input_batch, sample_hidden)
print ('Encoder output shape: (batch size, sequence length, units) {}'.format(sample_output.shape))
print ('Encoder Hidden state shape: (batch size, units) {}'.format(sample_hidden.shape))
# Out:
# Encoder output shape: (batch size, sequence length, units) (64, 15, 1024)
# Encoder Hidden state shape: (batch size, units) (64, 1024)

# %%
class BahdanauAttention(tf.keras.layers.Layer):
  def __init__(self, units):
    super(BahdanauAttention, self).__init__()
    self.W1 = tf.keras.layers.Dense(units)
    self.W2 = tf.keras.layers.Dense(units)
    self.V = tf.keras.layers.Dense(1)

  def call(self, query, values):
    # query hidden state shape == (batch_size, hidden size)
    # query_with_time_axis shape == (batch_size, 1, hidden size)
    # values shape == (batch_size, max_len, hidden size)
    # we are doing this to broadcast addition along the time axis to calculate the score
    query_with_time_axis = tf.expand_dims(query, 1)

    # score shape == (batch_size, max_length, 1)
    # we get 1 at the last axis because we are applying score to self.V
    # the shape of the tensor before applying self.V is (batch_size, max_length, units)
    score = self.V(tf.nn.tanh(
        self.W1(query_with_time_axis) + self.W2(values)))

    # attention_weights shape == (batch_size, max_length, 1)
    attention_weights = tf.nn.softmax(score, axis=1)

    # context_vector shape after sum == (batch_size, hidden_size)
    context_vector = attention_weights * values
    context_vector = tf.reduce_sum(context_vector, axis=1)

    return context_vector, attention_weights

# %%
attention_layer = BahdanauAttention(10)
attention_result, attention_weights = attention_layer(sample_hidden, sample_output)

print("Attention result shape: (batch size, units) {}".format(attention_result.shape))
print("Attention weights shape: (batch_size, sequence_length, 1) {}".format(attention_weights.shape))
# Out:
# Attention result shape: (batch size, units) (64, 1024)
# Attention weights shape: (batch_size, sequence_length, 1) (64, 15, 1)

# %%
class Decoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_dim, dec_units, batch_sz):
    super(Decoder, self).__init__()
    self.batch_sz = batch_sz
    self.dec_units = dec_units
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(self.dec_units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')
    self.fc = tf.keras.layers.Dense(vocab_size)

    # used for attention
    self.attention = BahdanauAttention(self.dec_units)

  def call(self, x, hidden, enc_output):
    # enc_output shape == (batch_size, max_length, hidden_size)
    context_vector, attention_weights = self.attention(hidden, enc_output)

    # x shape after passing through embedding == (batch_size, 1, embedding_dim)
    x = self.embedding(x)

    # x shape after concatenation == (batch_size, 1, embedding_dim + hidden_size)
    x = tf.concat([tf.expand_dims(context_vector, 1), x], axis=-1)

    # passing the concatenated vector to the GRU
    output, state = self.gru(x)

    # output shape == (batch_size * 1, hidden_size)
    output = tf.reshape(output, (-1, output.shape[2]))

    # output shape == (batch_size, vocab)
    x = self.fc(output)

    return x, state, attention_weights

# %%
decoder = Decoder(vocab_tar_size, embedding_dim, units, BATCH_SIZE)

sample_decoder_output, _, _ = decoder(tf.random.uniform((BATCH_SIZE, 1)),
                                      sample_hidden, sample_output)

print ('Decoder output shape: (batch_size, vocab size) {}'.format(sample_decoder_output.shape))
# Out:
# Decoder output shape: (batch_size, vocab size) (64, 7334)

# %% [markdown]
# ## Define the optimizer and the loss function

# %%
optimizer = tf.keras.optimizers.Adam()
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')

def loss_function(real, pred):
  mask = tf.math.logical_not(tf.math.equal(real, 0))
  loss_ = loss_object(real, pred)

  mask = tf.cast(mask, dtype=loss_.dtype)
  loss_ *= mask

  return tf.reduce_mean(loss_)

# %% [markdown]
# ## Checkpoints (Object-based saving)

# %%
checkpoint_dir = './training_attention_checkpoints'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                 encoder=encoder,
                                 decoder=decoder)

# %%
@tf.function
def train_step(inp, targ, enc_hidden):
  loss = 0

  with tf.GradientTape() as tape:
    enc_output, enc_hidden = encoder(inp, enc_hidden)

    dec_hidden = enc_hidden

    dec_input = tf.expand_dims([targ_lang.word_index['<start>']] * BATCH_SIZE, 1)

    # Teacher forcing - feeding the target as the next input
    for t in range(1, targ.shape[1]):
      # passing enc_output to the decoder
      predictions, dec_hidden, _ = decoder(dec_input, dec_hidden, enc_output)

      loss += loss_function(targ[:, t], predictions)

      # using teacher forcing
      dec_input = tf.expand_dims(targ[:, t], 1)

  batch_loss = (loss / int(targ.shape[1]))

  variables = encoder.trainable_variables + decoder.trainable_variables

  gradients = tape.gradient(loss, variables)

  optimizer.apply_gradients(zip(gradients, variables))

  return batch_loss

# %%
EPOCHS = 50

for epoch in range(EPOCHS):
  start = time.time()

  enc_hidden = encoder.initialize_hidden_state()
  total_loss = 0

  for (batch, (inp, targ)) in enumerate(dataset.take(steps_per_epoch)):
    batch_loss = train_step(inp, targ, enc_hidden)
    total_loss += batch_loss

    if batch % 100 == 0:
      print('Epoch {} Batch {} Loss {:.4f}'.format(epoch + 1,
                                                   batch,
                                                   batch_loss.numpy()))
  # saving (checkpoint) the model every 2 epochs
  if (epoch + 1) % 2 == 0:
    checkpoint.save(file_prefix = checkpoint_prefix)

  print('Epoch {} Loss {:.4f}'.format(epoch + 1,
                                      total_loss / steps_per_epoch))
  print('Time taken for 1 epoch {} sec\n'.format(time.time() - start))
# Out:
# Epoch 1 Batch 0 Loss 4.5895
# Epoch 1 Batch 100 Loss 2.1466
# Epoch 1 Batch 200 Loss 1.7905
# Epoch 1 Batch 300 Loss 1.6507
# Epoch 1 Batch 400 Loss 1.5913
# Epoch 1 Batch 500 Loss 1.4651
# Epoch 1 Batch 600 Loss 1.3612
# Epoch 1 Batch 700 Loss 1.3189
# Epoch 1 Batch 800 Loss 1.2018
# Epoch 1 Batch 900 Loss 1.1503
# Epoch 1 Batch 1000 Loss 1.0683
# Epoch 1 Batch 1100 Loss 0.9917
# Epoch 1 Batch 1200 Loss 1.0115
# Epoch 1 Loss 1.4468
# Time taken for 1 epoch 113.96503138542175 sec
#
# Epoch 2 Batch 0 Loss 0.7674
# Epoch 2 Batch 100 Loss 0.6982
# Epoch 2 Batch 200 Loss 0.7642
# Epoch 2 Batch 300 Loss 0.8280
# Epoch 2 Batch 400 Loss 0.5948
# Epoch 2 Batch 500 Loss 0.5740
# Epoch 2 Batch 600 Loss 0.6623
# Epoch 2 Batch 700 Loss 0.5107
# Epoch 2 Batch 800 Loss 0.4119
# Epoch 2 Batch 900 Loss 0.5721
# Epoch 2 Batch 1000 Loss 0.4790
# Epoch 2 Batch 1100 Loss 0.5445
# Epoch 2 Batch 1200 Loss 0.5983
# Epoch 2 Loss 0.6188
# Time taken for 1 epoch 97.89462113380432 sec
#
# Epoch 3 Batch 0 Loss 0.3080
# Epoch 3 Batch 100 Loss 0.2888
# Epoch 3 Batch 200 Loss 0.2808
# Epoch 3 Batch 300 Loss 0.2770
# Epoch 3 Batch 400 Loss 0.2815
# Epoch 3 Batch 500 Loss 0.3247
# Epoch 3 Batch 600 Loss 0.3349
# Epoch 3 Batch 700 Loss 0.3121
# Epoch 3 Batch 800 Loss 0.3889
# Epoch 3 Batch 900 Loss 0.3581
# Epoch 3 Batch 1000 Loss 0.3183
# Epoch 3 Batch 1100 Loss 0.2331
# Epoch 3 Batch 1200 Loss 0.2544
# Epoch 3 Loss 0.3221
# Time taken for 1 epoch 96.99507880210876 sec
#
# Epoch 4 Batch 0 Loss 0.2295
# Epoch 4 Batch 100 Loss 0.1661
# Epoch 4 Batch 200 Loss 0.1536
# Epoch 4 Batch 300 Loss 0.2269
# Epoch 4 Batch 400 Loss 0.1790
# Epoch 4 Batch 500 Loss 0.2427
# Epoch 4 Batch 600 Loss 0.2398
# Epoch 4 Batch 700 Loss 0.2767
# Epoch 4 Batch 800 Loss 0.1458
# Epoch 4 Batch 900 Loss 0.2088
# Epoch 4 Batch 1000 Loss 0.2380
# Epoch 4 Batch 1100 Loss 0.2345
# Epoch 4 Batch 1200 Loss 0.1922
# Epoch 4 Loss 0.2014
# Time taken for 1 epoch 97.82314562797546 sec
#
# Epoch 5 Batch 0 Loss 0.1190
# Epoch 5 Batch 100 Loss 0.1285
# Epoch 5 Batch 200 Loss 0.1115
# Epoch 5 Batch 300 Loss 0.1032
# Epoch 5 Batch 400 Loss 0.0903
# Epoch 5 Batch 500 Loss 0.1360
# Epoch 5 Batch 600 Loss 0.1075
# Epoch 5 Batch 700 Loss 0.1130
# Epoch 5 Batch 800 Loss 0.1679
# Epoch 5 Batch 900 Loss 0.1469
# Epoch 5 Batch 1000 Loss 0.1690
# Epoch 5 Batch 1100 Loss 0.1190
# Epoch 5 Batch 1200 Loss 0.1373
# Epoch 5 Loss 0.1452
# Time taken for 1 epoch 97.21083736419678 sec
#
# Epoch 6 Batch 0 Loss 0.0915
# Epoch 6 Batch 100 Loss 0.0861
# Epoch 6 Batch 200 Loss 0.1495
# Epoch 6 Batch 300 Loss 0.0856
# Epoch 6 Batch 400 Loss 0.1012
# Epoch 6 Batch 500 Loss 0.1005
# Epoch 6 Batch 600 Loss 0.1362
# Epoch 6 Batch 700 Loss 0.1299
# Epoch 6 Batch 800 Loss 0.1579
# Epoch 6 Batch 900 Loss 0.1406
# Epoch 6 Batch 1000 Loss 0.1228
# Epoch 6 Batch 1100 Loss 0.1585
# Epoch 6 Batch 1200 Loss 0.1541
# Epoch 6 Loss 0.1164
# Time taken for 1 epoch 98.02658247947693 sec
#
# Epoch 7 Batch 0 Loss 0.0897
# Epoch 7 Batch 100 Loss 0.0729
# Epoch 7 Batch 200 Loss 0.0943
# Epoch 7 Batch 300 Loss 0.0933
# Epoch 7 Batch 400 Loss 0.1140
# Epoch 7 Batch 500 Loss 0.0969
# Epoch 7 Batch 600 Loss 0.0925
# Epoch 7 Batch 700 Loss 0.0612
# Epoch 7 Batch 800 Loss 0.0757
# Epoch 7 Batch 900 Loss 0.0745
# Epoch 7 Batch 1000 Loss 0.0875
# Epoch 7 Batch 1100 Loss 0.1479
# Epoch 7 Batch 1200 Loss 0.1185
# Epoch 7 Loss 0.0994
# Time taken for 1 epoch 97.14057302474976 sec
#
# Epoch 8 Batch 0 Loss 0.0931
# Epoch 8 Batch 100 Loss 0.1070
# Epoch 8 Batch 200 Loss 0.1109
# Epoch 8 Batch 300 Loss 0.0520
# Epoch 8 Batch 400 Loss 0.0992
# Epoch 8 Batch 500 Loss 0.1088
# Epoch 8 Batch 600 Loss 0.0530
# Epoch 8 Batch 700 Loss 0.0827
# Epoch 8 Batch 800 Loss 0.0729
# Epoch 8 Batch 900 Loss 0.1470
# Epoch 8 Batch 1000 Loss 0.1403
# Epoch 8 Batch 1100 Loss 0.0971
# Epoch 8 Batch 1200 Loss 0.0682
# Epoch 8 Loss 0.0888
# Time taken for 1 epoch 97.73235416412354 sec
#
# Epoch 9 Batch 0 Loss 0.0613
# Epoch 9 Batch 100 Loss 0.0973
# Epoch 9 Batch 200 Loss 0.0818
# Epoch 9 Batch 300 Loss 0.0512
# Epoch 9 Batch 400 Loss 0.0994
# Epoch 9 Batch 500 Loss 0.0715
# Epoch 9 Batch 600 Loss 0.0965
# Epoch 9 Batch 700 Loss 0.0950
# Epoch 9 Batch 800 Loss 0.1132
# Epoch 9 Batch 900 Loss 0.1415
# Epoch 9 Batch 1000 Loss 0.1016
# Epoch 9 Batch 1100 Loss 0.0944
# Epoch 9 Batch 1200 Loss 0.1188
# Epoch 9 Loss 0.0827
# Time taken for 1 epoch 97.06475853919983 sec
#
# Epoch 10 Batch 0 Loss 0.0514
# Epoch 10 Batch 100 Loss 0.0491
# Epoch 10 Batch 200 Loss 0.0570
# Epoch 10 Batch 300 Loss 0.0800
# Epoch 10 Batch 400 Loss 0.0524
# Epoch 10 Batch 500 Loss 0.0734
# Epoch 10 Batch 600 Loss 0.1048
# Epoch 10 Batch 700 Loss 0.0693
# Epoch 10 Batch 800 Loss 0.0817
# Epoch 10 Batch 900 Loss 0.1011
# Epoch 10 Batch 1000 Loss 0.0968
# Epoch 10 Batch 1100 Loss 0.0778
# Epoch 10 Batch 1200 Loss 0.1053
# Epoch 10 Loss 0.0777
# Time taken for 1 epoch 97.767254114151 sec
#
# Epoch 11 Batch 0 Loss 0.0524
# Epoch 11 Batch 100 Loss 0.0533
# Epoch 11 Batch 200 Loss 0.0591
# Epoch 11 Batch 300 Loss 0.0195
# Epoch 11 Batch 400 Loss 0.0585
# Epoch 11 Batch 500 Loss 0.0712
# Epoch 11 Batch 600 Loss 0.0628
# Epoch 11 Batch 700 Loss 0.1351
# Epoch 11 Batch 800 Loss 0.0783
# Epoch 11 Batch 900 Loss 0.0850
# Epoch 11 Batch 1000 Loss 0.0861
# Epoch 11 Batch 1100 Loss 0.0911
# Epoch 11 Batch 1200 Loss 0.0911
# Epoch 11 Loss 0.0735
# Time taken for 1 epoch 97.1174705028534 sec
#
# Epoch 12 Batch 0 Loss 0.0365
# Epoch 12 Batch 100 Loss 0.0659
# Epoch 12 Batch 200 Loss 0.0574
# Epoch 12 Batch 300 Loss 0.0479
# Epoch 12 Batch 400 Loss 0.1029
# Epoch 12 Batch 500 Loss 0.0559
# Epoch 12 Batch 600 Loss 0.0543
# Epoch 12 Batch 700 Loss 0.0618
# Epoch 12 Batch 800 Loss 0.0777
# Epoch 12 Batch 900 Loss 0.0909
# Epoch 12 Batch 1000 Loss 0.0782
# Epoch 12 Batch 1100 Loss 0.0702
# Epoch 12 Batch 1200 Loss 0.0776
# Epoch 12 Loss 0.0692
# Time taken for 1 epoch 97.99853205680847 sec
#
# Epoch 13 Batch 0 Loss 0.0359
# Epoch 13 Batch 100 Loss 0.0247
# Epoch 13 Batch 200 Loss 0.0752
# Epoch 13 Batch 300 Loss 0.0587
# Epoch 13 Batch 400 Loss 0.0906
# Epoch 13 Batch 500 Loss 0.0634
# Epoch 13 Batch 600 Loss 0.0579
# Epoch 13 Batch 700 Loss 0.0773
# Epoch 13 Batch 800 Loss 0.0790
# Epoch 13 Batch 900 Loss 0.0610
# Epoch 13 Batch 1000 Loss 0.0705
# Epoch 13 Batch 1100 Loss 0.0670
# Epoch 13 Batch 1200 Loss 0.1074
# Epoch 13 Loss 0.0671
# Time taken for 1 epoch 97.12426209449768 sec
#
# Epoch 14 Batch 0 Loss 0.0723
# Epoch 14 Batch 100 Loss 0.0400
# Epoch 14 Batch 200 Loss 0.0267
# Epoch 14 Batch 300 Loss 0.0674
# Epoch 14 Batch 400 Loss 0.0989
# Epoch 14 Batch 500 Loss 0.1066
# Epoch 14 Batch 600 Loss 0.0416
# Epoch 14 Batch 700 Loss 0.0722
# Epoch 14 Batch 800 Loss 0.0780
# Epoch 14 Batch 900 Loss 0.0915
# Epoch 14 Batch 1000 Loss 0.0935
# Epoch 14 Batch 1100 Loss 0.0483
# Epoch 14 Batch 1200 Loss 0.0914
# Epoch 14 Loss 0.0646
# Time taken for 1 epoch 97.79003524780273 sec
#
# Epoch 15 Batch 0 Loss 0.0593
# Epoch 15 Batch 100 Loss 0.0422
# Epoch 15 Batch 200 Loss 0.0398
# Epoch 15 Batch 300 Loss 0.0637
# Epoch 15 Batch 400 Loss 0.0531
# Epoch 15 Batch 500 Loss 0.0820
# Epoch 15 Batch 600 Loss 0.0734
# Epoch 15 Batch 700 Loss 0.0668
# Epoch 15 Batch 800 Loss 0.0476
# Epoch 15 Batch 900 Loss 0.0695
# Epoch 15 Batch 1000 Loss 0.0636
# Epoch 15 Batch 1100 Loss 0.0784
# Epoch 15 Batch 1200 Loss 0.1001
# Epoch 15 Loss 0.0623
# Time taken for 1 epoch 97.09040951728821 sec
#
# Epoch 16 Batch 0 Loss 0.0486
# Epoch 16 Batch 100 Loss 0.0487
# Epoch 16 Batch 200 Loss 0.0569
# Epoch 16 Batch 300 Loss 0.0539
# Epoch 16 Batch 400 Loss 0.0543
# Epoch 16 Batch 500 Loss 0.0567
# Epoch 16 Batch 600 Loss 0.0521
# Epoch 16 Batch 700 Loss 0.0552
# Epoch 16 Batch 800 Loss 0.0437
# Epoch 16 Batch 900 Loss 0.0644
# Epoch 16 Batch 1000 Loss 0.0805
# Epoch 16 Batch 1100 Loss 0.0651
# Epoch 16 Batch 1200 Loss 0.0750
# Epoch 16 Loss 0.0614
# Time taken for 1 epoch 97.75999999046326 sec
#
# Epoch 17 Batch 0 Loss 0.0289
# Epoch 17 Batch 100 Loss 0.0416
# Epoch 17 Batch 200 Loss 0.0451
# Epoch 17 Batch 300 Loss 0.0330
# Epoch 17 Batch 400 Loss 0.0714
# Epoch 17 Batch 500 Loss 0.0688
# Epoch 17 Batch 600 Loss 0.0601
# Epoch 17 Batch 700 Loss 0.0434
# Epoch 17 Batch 800 Loss 0.0451
# Epoch 17 Batch 900 Loss 0.0541
# Epoch 17 Batch 1000 Loss 0.0639
# Epoch 17 Batch 1100 Loss 0.1037
# Epoch 17 Batch 1200 Loss 0.0421
# Epoch 17 Loss 0.0578
# Time taken for 1 epoch 97.06305170059204 sec
#
# Epoch 18 Batch 0 Loss 0.0580
# Epoch 18 Batch 100 Loss 0.0394
# Epoch 18 Batch 200 Loss 0.0508
# Epoch 18 Batch 300 Loss 0.0480
# Epoch 18 Batch 400 Loss 0.0593
# Epoch 18 Batch 500 Loss 0.0474
# Epoch 18 Batch 600 Loss 0.0408
# Epoch 18 Batch 700 Loss 0.0447
# Epoch 18 Batch 800 Loss 0.0577
# Epoch 18 Batch 900 Loss 0.0615
# Epoch 18 Batch 1000 Loss 0.0418
# Epoch 18 Batch 1100 Loss 0.0527
# Epoch 18 Batch 1200 Loss 0.0804
# Epoch 18 Loss 0.0571
# Time taken for 1 epoch 97.82750272750854 sec
#
# Epoch 19 Batch 0 Loss 0.0576
# Epoch 19 Batch 100 Loss 0.0445
# Epoch 19 Batch 200 Loss 0.0613
# Epoch 19 Batch 300 Loss 0.0407
# Epoch 19 Batch 400 Loss 0.0338
# Epoch 19 Batch 500 Loss 0.0565
# Epoch 19 Batch 600 Loss 0.0881
# Epoch 19 Batch 700 Loss 0.0789
# Epoch 19 Batch 800 Loss 0.0591
# Epoch 19 Batch 900 Loss 0.0502
# Epoch 19 Batch 1000 Loss 0.1014
# Epoch 19 Batch 1100 Loss 0.0464
# Epoch 19 Batch 1200 Loss 0.0756
# Epoch 19 Loss 0.0562
# Time taken for 1 epoch 97.09152936935425 sec
#
# Epoch 20 Batch 0 Loss 0.0525
# Epoch 20 Batch 100 Loss 0.0566
# Epoch 20 Batch 200 Loss 0.0317
# Epoch 20 Batch 300 Loss 0.0399
# Epoch 20 Batch 400 Loss 0.0378
# Epoch 20 Batch 500 Loss 0.0401
# Epoch 20 Batch 600 Loss 0.0326
# Epoch 20 Batch 700 Loss 0.0504
# Epoch 20 Batch 800 Loss 0.0847
# Epoch 20 Batch 900 Loss 0.0285
# Epoch 20 Batch 1000 Loss 0.0589
# Epoch 20 Batch 1100 Loss 0.0607
# Epoch 20 Batch 1200 Loss 0.0592
# Epoch 20 Loss 0.0546
# Time taken for 1 epoch 97.89237236976624 sec
#
# Epoch 21 Batch 0 Loss 0.0201
# Epoch 21 Batch 100 Loss 0.0362
# Epoch 21 Batch 200 Loss 0.0479
# Epoch 21 Batch 300 Loss 0.0289
# Epoch 21 Batch 400 Loss 0.0530
# Epoch 21 Batch 500 Loss 0.0534
# Epoch 21 Batch 600 Loss 0.0624
# Epoch 21 Batch 700 Loss 0.0663
# Epoch 21 Batch 800 Loss 0.0936
# Epoch 21 Batch 900 Loss 0.0860
# Epoch 21 Batch 1000 Loss 0.0701
# Epoch 21 Batch 1100 Loss 0.0857
# Epoch 21 Batch 1200 Loss 0.0688
# Epoch 21 Loss 0.0528
# Time taken for 1 epoch 97.08333992958069 sec
#
# Epoch 22 Batch 0 Loss 0.0585
# Epoch 22 Batch 100 Loss 0.0522
# Epoch 22 Batch 200 Loss 0.0479
# Epoch 22 Batch 300 Loss 0.0689
# Epoch 22 Batch 400 Loss 0.0389
# Epoch 22 Batch 500 Loss 0.0401
# Epoch 22 Batch 600 Loss 0.0726
# Epoch 22 Batch 700 Loss 0.0606
# Epoch 22 Batch 800 Loss 0.0537
# Epoch 22 Batch 900 Loss 0.0972
# Epoch 22 Batch 1000 Loss 0.0507
# Epoch 22 Batch 1100 Loss 0.0749
# Epoch 22 Batch 1200 Loss 0.0606
# Epoch 22 Loss 0.0526
# Time taken for 1 epoch 97.68599009513855 sec
#
# Epoch 23 Batch 0 Loss 0.0621
# Epoch 23 Batch 100 Loss 0.0322
# Epoch 23 Batch 200 Loss 0.0518
# Epoch 23 Batch 300 Loss 0.0551
# Epoch 23 Batch 400 Loss 0.0625
# Epoch 23 Batch 500 Loss 0.0363
# Epoch 23 Batch 600 Loss 0.0625
# Epoch 23 Batch 700 Loss 0.0419
# Epoch 23 Batch 800 Loss 0.0358
# Epoch 23 Batch 900 Loss 0.0412
# Epoch 23 Batch 1000 Loss 0.0611
# Epoch 23 Batch 1100 Loss 0.0651
# Epoch 23 Batch 1200 Loss 0.0568
# Epoch 23 Loss 0.0520
# Time taken for 1 epoch 97.03302955627441 sec
#
# Epoch 24 Batch 0 Loss 0.0421
# Epoch 24 Batch 100 Loss 0.0297
# Epoch 24 Batch 200 Loss 0.0659
# Epoch 24 Batch 300 Loss 0.0585
# Epoch 24 Batch 400 Loss 0.0528
# Epoch 24 Batch 500 Loss 0.0648
# Epoch 24 Batch 600 Loss 0.0447
# Epoch 24 Batch 700 Loss 0.0629
# Epoch 24 Batch 800 Loss 0.0418
# Epoch 24 Batch 900 Loss 0.0998
# Epoch 24 Batch 1000 Loss 0.0578
# Epoch 24 Batch 1100 Loss 0.0605
# Epoch 24 Batch 1200 Loss 0.0455
# Epoch 24 Loss 0.0505
# Time taken for 1 epoch 97.68296790122986 sec
#
# Epoch 25 Batch 0 Loss 0.0397
# Epoch 25 Batch 100 Loss 0.0332
# Epoch 25 Batch 200 Loss 0.0493
# Epoch 25 Batch 300 Loss 0.0677
# Epoch 25 Batch 400 Loss 0.0474
# Epoch 25 Batch 500 Loss 0.0562
# Epoch 25 Batch 600 Loss 0.0362
# Epoch 25 Batch 700 Loss 0.0375
# Epoch 25 Batch 800 Loss 0.0633
# Epoch 25 Batch 900 Loss 0.0408
# Epoch 25 Batch 1000 Loss 0.0385
# Epoch 25 Batch 1100 Loss 0.0405
# Epoch 25 Batch 1200 Loss 0.0612
# Epoch 25 Loss 0.0495
# Time taken for 1 epoch 97.09508299827576 sec
#
# Epoch 26 Batch 0 Loss 0.0360
# Epoch 26 Batch 100 Loss 0.0443
# Epoch 26 Batch 200 Loss 0.0365
# Epoch 26 Batch 300 Loss 0.0283
# Epoch 26 Batch 400 Loss 0.0526
# Epoch 26 Batch 500 Loss 0.0429
# Epoch 26 Batch 600 Loss 0.0530
# Epoch 26 Batch 700 Loss 0.0401
# Epoch 26 Batch 800 Loss 0.0553
# Epoch 26 Batch 900 Loss 0.0748
# Epoch 26 Batch 1000 Loss 0.0350
# Epoch 26 Batch 1100 Loss 0.0418
# Epoch 26 Batch 1200 Loss 0.0387
# Epoch 26 Loss 0.0491
# Time taken for 1 epoch 97.79034948348999 sec
#
# Epoch 27 Batch 0 Loss 0.0259
# Epoch 27 Batch 100 Loss 0.0529
# Epoch 27 Batch 200 Loss 0.0401
# Epoch 27 Batch 300 Loss 0.0236
# Epoch 27 Batch 400 Loss 0.0620
# Epoch 27 Batch 500 Loss 0.0501
# Epoch 27 Batch 600 Loss 0.0365
# Epoch 27 Batch 700 Loss 0.0229
# Epoch 27 Batch 800 Loss 0.0589
# Epoch 27 Batch 900 Loss 0.0493
# Epoch 27 Batch 1000 Loss 0.0507
# Epoch 27 Batch 1100 Loss 0.0509
# Epoch 27 Batch 1200 Loss 0.0525
# Epoch 27 Loss 0.0480
# Time taken for 1 epoch 97.03875613212585 sec
#
# Epoch 28 Batch 0 Loss 0.0380
# Epoch 28 Batch 100 Loss 0.0519
# Epoch 28 Batch 200 Loss 0.0300
# Epoch 28 Batch 300 Loss 0.0544
# Epoch 28 Batch 400 Loss 0.0242
# Epoch 28 Batch 500 Loss 0.0291
# Epoch 28 Batch 600 Loss 0.0280
# Epoch 28 Batch 700 Loss 0.0485
# Epoch 28 Batch 800 Loss 0.0429
# Epoch 28 Batch 900 Loss 0.0381
# Epoch 28 Batch 1000 Loss 0.0857
# Epoch 28 Batch 1100 Loss 0.0578
# Epoch 28 Batch 1200 Loss 0.0529
# Epoch 28 Loss 0.0473
# Time taken for 1 epoch 97.72780728340149 sec
#
# Epoch 29 Batch 0 Loss 0.0509
# Epoch 29 Batch 100 Loss 0.0414
# Epoch 29 Batch 200 Loss 0.0554
# Epoch 29 Batch 300 Loss 0.0288
# Epoch 29 Batch 400 Loss 0.0414
# Epoch 29 Batch 500 Loss 0.0503
# Epoch 29 Batch 600 Loss 0.0323
# Epoch 29 Batch 700 Loss 0.0528
# Epoch 29 Batch 800 Loss 0.0539
# Epoch 29 Batch 900 Loss 0.0689
# Epoch 29 Batch 1000 Loss 0.0676
# Epoch 29 Batch 1100 Loss 0.0374
# Epoch 29 Batch 1200 Loss 0.0570
# Epoch 29 Loss 0.0468
# Time taken for 1 epoch 97.09181427955627 sec
#
# Epoch 30 Batch 0 Loss 0.0287
# Epoch 30 Batch 100 Loss 0.0512
# Epoch 30 Batch 200 Loss 0.0556
# Epoch 30 Batch 300 Loss 0.0727
# Epoch 30 Batch 400 Loss 0.0382
# Epoch 30 Batch 500 Loss 0.0737
# Epoch 30 Batch 600 Loss 0.0440
# Epoch 30 Batch 700 Loss 0.0628
# Epoch 30 Batch 800 Loss 0.0596
# Epoch 30 Batch 900 Loss 0.0668
# Epoch 30 Batch 1000 Loss 0.0454
# Epoch 30 Batch 1100 Loss 0.0514
# Epoch 30 Batch 1200 Loss 0.0462
# Epoch 30 Loss 0.0465
# Time taken for 1 epoch 97.73203325271606 sec
#
# Epoch 31 Batch 0 Loss 0.0234
# Epoch 31 Batch 100 Loss 0.0441
# Epoch 31 Batch 200 Loss 0.0412
# Epoch 31 Batch 300 Loss 0.0313
# Epoch 31 Batch 400 Loss 0.0460
# Epoch 31 Batch 500 Loss 0.0328
# Epoch 31 Batch 600 Loss 0.0307
# Epoch 31 Batch 700 Loss 0.0644
# Epoch 31 Batch 800 Loss 0.0281
# Epoch 31 Batch 900 Loss 0.0396
# Epoch 31 Batch 1000 Loss 0.0589
# Epoch 31 Batch 1100 Loss 0.0433
# Epoch 31 Batch 1200 Loss 0.0595
# Epoch 31 Loss 0.0454
# Time taken for 1 epoch 97.04239678382874 sec
#
# Epoch 32 Batch 0 Loss 0.0302
# Epoch 32 Batch 100 Loss 0.0331
# Epoch 32 Batch 200 Loss 0.0568
# Epoch 32 Batch 300 Loss 0.0373
# Epoch 32 Batch 400 Loss 0.0315
# Epoch 32 Batch 500 Loss 0.0303
# Epoch 32 Batch 600 Loss 0.0216
# Epoch 32 Batch 700 Loss 0.0513
# Epoch 32 Batch 800 Loss 0.0449
# Epoch 32 Batch 900 Loss 0.0342
# Epoch 32 Batch 1000 Loss 0.0528
# Epoch 32 Batch 1100 Loss 0.0530
# Epoch 32 Batch 1200 Loss 0.0629
# Epoch 32 Loss 0.0449
# Time taken for 1 epoch 97.76749420166016 sec
#
# Epoch 33 Batch 0 Loss 0.0228
# Epoch 33 Batch 100 Loss 0.0356
# Epoch 33 Batch 200 Loss 0.0527
# Epoch 33 Batch 300 Loss 0.0437
# Epoch 33 Batch 400 Loss 0.0355
# Epoch 33 Batch 500 Loss 0.0463
# Epoch 33 Batch 600 Loss 0.0634
# Epoch 33 Batch 700 Loss 0.0399
# Epoch 33 Batch 800 Loss 0.0507
# Epoch 33 Batch 900 Loss 0.0620
# Epoch 33 Batch 1000 Loss 0.0267
# Epoch 33 Batch 1100 Loss 0.0374
# Epoch 33 Batch 1200 Loss 0.0397
# Epoch 33 Loss 0.0452
# Time taken for 1 epoch 97.09839153289795 sec
#
# Epoch 34 Batch 0 Loss 0.0601
# Epoch 34 Batch 100 Loss 0.0246
# Epoch 34 Batch 200 Loss 0.0458
# Epoch 34 Batch 300 Loss 0.0243
# Epoch 34 Batch 400 Loss 0.0497
# Epoch 34 Batch 500 Loss 0.0765
# Epoch 34 Batch 600 Loss 0.0234
# Epoch 34 Batch 700 Loss 0.0581
# Epoch 34 Batch 800 Loss 0.0377
# Epoch 34 Batch 900 Loss 0.0470
# Epoch 34 Batch 1000 Loss 0.0504
# Epoch 34 Batch 1100 Loss 0.0512
# Epoch 34 Batch 1200 Loss 0.0374
# Epoch 34 Loss 0.0444
# Time taken for 1 epoch 97.89116716384888 sec
#
# Epoch 35 Batch 0 Loss 0.0183
# Epoch 35 Batch 100 Loss 0.0296
# Epoch 35 Batch 200 Loss 0.0271
# Epoch 35 Batch 300 Loss 0.0418
# Epoch 35 Batch 400 Loss 0.0333
# Epoch 35 Batch 500 Loss 0.0384
# Epoch 35 Batch 600 Loss 0.0385
# Epoch 35 Batch 700 Loss 0.0441
# Epoch 35 Batch 800 Loss 0.0356
# Epoch 35 Batch 900 Loss 0.0517
# Epoch 35 Batch 1000 Loss 0.0780
# Epoch 35 Batch 1100 Loss 0.0600
# Epoch 35 Batch 1200 Loss 0.0542
# Epoch 35 Loss 0.0437
# Time taken for 1 epoch 97.05170917510986 sec
#
# Epoch 36 Batch 0 Loss 0.0207
# Epoch 36 Batch 100 Loss 0.0236
# Epoch 36 Batch 200 Loss 0.0385
# Epoch 36 Batch 300 Loss 0.0734
# Epoch 36 Batch 400 Loss 0.0663
# Epoch 36 Batch 500 Loss 0.0539
# Epoch 36 Batch 600 Loss 0.0306
# Epoch 36 Batch 700 Loss 0.0495
# Epoch 36 Batch 800 Loss 0.0635
# Epoch 36 Batch 900 Loss 0.0448
# Epoch 36 Batch 1000 Loss 0.0708
# Epoch 36 Batch 1100 Loss 0.0661
# Epoch 36 Batch 1200 Loss 0.0617
# Epoch 36 Loss 0.0437
# Time taken for 1 epoch 97.67569851875305 sec
#
# Epoch 37 Batch 0 Loss 0.0365
# Epoch 37 Batch 100 Loss 0.0226
# Epoch 37 Batch 200 Loss 0.0150
# Epoch 37 Batch 300 Loss 0.0287
# Epoch 37 Batch 400 Loss 0.0351
# Epoch 37 Batch 500 Loss 0.0317
# Epoch 37 Batch 600 Loss 0.0432
# Epoch 37 Batch 700 Loss 0.0450
# Epoch 37 Batch 800 Loss 0.0501
# Epoch 37 Batch 900 Loss 0.0532
# Epoch 37 Batch 1000 Loss 0.0631
# Epoch 37 Batch 1100 Loss 0.0427
# Epoch 37 Batch 1200 Loss 0.0469
# Epoch 37 Loss 0.0427
# Time taken for 1 epoch 97.00288653373718 sec
#
# Epoch 38 Batch 0 Loss 0.0226
# Epoch 38 Batch 100 Loss 0.0404
# Epoch 38 Batch 200 Loss 0.0409
# Epoch 38 Batch 300 Loss 0.0561
# Epoch 38 Batch 400 Loss 0.0217
# Epoch 38 Batch 500 Loss 0.0529
# Epoch 38 Batch 600 Loss 0.0411
# Epoch 38 Batch 700 Loss 0.0370
# Epoch 38 Batch 800 Loss 0.0412
# Epoch 38 Batch 900 Loss 0.0532
# Epoch 38 Batch 1000 Loss 0.0596
# Epoch 38 Batch 1100 Loss 0.0727
# Epoch 38 Batch 1200 Loss 0.0387
# Epoch 38 Loss 0.0425
# Time taken for 1 epoch 97.8685200214386 sec
#
# Epoch 39 Batch 0 Loss 0.0276
# Epoch 39 Batch 100 Loss 0.0612
# Epoch 39 Batch 200 Loss 0.0529
# Epoch 39 Batch 300 Loss 0.0324
# Epoch 39 Batch 400 Loss 0.0309
# Epoch 39 Batch 500 Loss 0.0261
# Epoch 39 Batch 600 Loss 0.0287
# Epoch 39 Batch 700 Loss 0.0273
# Epoch 39 Batch 800 Loss 0.0457
# Epoch 39 Batch 900 Loss 0.0342
# Epoch 39 Batch 1000 Loss 0.0536
# Epoch 39 Batch 1100 Loss 0.0502
# Epoch 39 Batch 1200 Loss 0.0690
# Epoch 39 Loss 0.0413
# Time taken for 1 epoch 96.88831210136414 sec
#
# Epoch 40 Batch 0 Loss 0.0146
# Epoch 40 Batch 100 Loss 0.0213
# Epoch 40 Batch 200 Loss 0.0403
# Epoch 40 Batch 300 Loss 0.0355
# Epoch 40 Batch 400 Loss 0.0236
# Epoch 40 Batch 500 Loss 0.0409
# Epoch 40 Batch 600 Loss 0.0505
# Epoch 40 Batch 700 Loss 0.0501
# Epoch 40 Batch 800 Loss 0.0321
# Epoch 40 Batch 900 Loss 0.0542
# Epoch 40 Batch 1000 Loss 0.0414
# Epoch 40 Batch 1100 Loss 0.0608
# Epoch 40 Batch 1200 Loss 0.0473
# Epoch 40 Loss 0.0409
# Time taken for 1 epoch 97.6403956413269 sec
#
# Epoch 41 Batch 0 Loss 0.0267
# Epoch 41 Batch 100 Loss 0.0295
# Epoch 41 Batch 200 Loss 0.0233
# Epoch 41 Batch 300 Loss 0.0457
# Epoch 41 Batch 400 Loss 0.0847
# Epoch 41 Batch 500 Loss 0.0253
# Epoch 41 Batch 600 Loss 0.0302
# Epoch 41 Batch 700 Loss 0.0566
# Epoch 41 Batch 800 Loss 0.0441
# Epoch 41 Batch 900 Loss 0.0424
# Epoch 41 Batch 1000 Loss 0.0570
# Epoch 41 Batch 1100 Loss 0.0528
# Epoch 41 Batch 1200 Loss 0.0497
# Epoch 41 Loss 0.0420
# Time taken for 1 epoch 96.99029731750488 sec
#
# Epoch 42 Batch 0 Loss 0.0358
# Epoch 42 Batch 100 Loss 0.0232
# Epoch 42 Batch 200 Loss 0.0217
# Epoch 42 Batch 300 Loss 0.0345
# Epoch 42 Batch 400 Loss 0.0296
# Epoch 42 Batch 500 Loss 0.0360
# Epoch 42 Batch 600 Loss 0.0289
# Epoch 42 Batch 700 Loss 0.0451
# Epoch 42 Batch 800 Loss 0.0453
# Epoch 42 Batch 900 Loss 0.0282
# Epoch 42 Batch 1000 Loss 0.0494
# Epoch 42 Batch 1100 Loss 0.0575
# Epoch 42 Batch 1200 Loss 0.0706
# Epoch 42 Loss 0.0403
# Time taken for 1 epoch 97.66237473487854 sec
#
# Epoch 43 Batch 0 Loss 0.0303
# Epoch 43 Batch 100 Loss 0.0437
# Epoch 43 Batch 200 Loss 0.0480
# Epoch 43 Batch 300 Loss 0.0560
# Epoch 43 Batch 400 Loss 0.0366
# Epoch 43 Batch 500 Loss 0.0366
# Epoch 43 Batch 600 Loss 0.0560
# Epoch 43 Batch 700 Loss 0.0187
# Epoch 43 Batch 800 Loss 0.0414
# Epoch 43 Batch 900 Loss 0.0769
# Epoch 43 Batch 1000 Loss 0.0541
# Epoch 43 Batch 1100 Loss 0.0430
# Epoch 43 Batch 1200 Loss 0.0243
# Epoch 43 Loss 0.0412
# Time taken for 1 epoch 96.9081962108612 sec
#
# Epoch 44 Batch 0 Loss 0.0377
# Epoch 44 Batch 100 Loss 0.0392
# Epoch 44 Batch 200 Loss 0.0242
# Epoch 44 Batch 300 Loss 0.0292
# Epoch 44 Batch 400 Loss 0.0544
# Epoch 44 Batch 500 Loss 0.0561
# Epoch 44 Batch 600 Loss 0.0594
# Epoch 44 Batch 700 Loss 0.0414
# Epoch 44 Batch 800 Loss 0.0311
# Epoch 44 Batch 900 Loss 0.0618
# Epoch 44 Batch 1000 Loss 0.0338
# Epoch 44 Batch 1100 Loss 0.0432
# Epoch 44 Batch 1200 Loss 0.0576
# Epoch 44 Loss 0.0403
# Time taken for 1 epoch 97.66049456596375 sec
#
# Epoch 45 Batch 0 Loss 0.0305
# Epoch 45 Batch 100 Loss 0.0295
# Epoch 45 Batch 200 Loss 0.0363
# Epoch 45 Batch 300 Loss 0.0458
# Epoch 45 Batch 400 Loss 0.0389
# Epoch 45 Batch 500 Loss 0.0583
# Epoch 45 Batch 600 Loss 0.0462
# Epoch 45 Batch 700 Loss 0.0464
# Epoch 45 Batch 800 Loss 0.0319
# Epoch 45 Batch 900 Loss 0.0256
# Epoch 45 Batch 1000 Loss 0.0386
# Epoch 45 Batch 1100 Loss 0.0549
# Epoch 45 Batch 1200 Loss 0.0493
# Epoch 45 Loss 0.0401
# Time taken for 1 epoch 96.96996784210205 sec
#
# Epoch 46 Batch 0 Loss 0.0200
# Epoch 46 Batch 100 Loss 0.0276
# Epoch 46 Batch 200 Loss 0.0471
# Epoch 46 Batch 300 Loss 0.0295
# Epoch 46 Batch 400 Loss 0.0489
# Epoch 46 Batch 500 Loss 0.0513
# Epoch 46 Batch 600 Loss 0.0363
# Epoch 46 Batch 700 Loss 0.0521
# Epoch 46 Batch 800 Loss 0.0541
# Epoch 46 Batch 900 Loss 0.0192
# Epoch 46 Batch 1000 Loss 0.0348
# Epoch 46 Batch 1100 Loss 0.0337
# Epoch 46 Batch 1200 Loss 0.0684
# Epoch 46 Loss 0.0395
# Time taken for 1 epoch 97.87953448295593 sec
#
# Epoch 47 Batch 0 Loss 0.0210
# Epoch 47 Batch 100 Loss 0.0271
# Epoch 47 Batch 200 Loss 0.0148
# Epoch 47 Batch 300 Loss 0.0221
# Epoch 47 Batch 400 Loss 0.0327
# Epoch 47 Batch 500 Loss 0.0162
# Epoch 47 Batch 600 Loss 0.0383
# Epoch 47 Batch 700 Loss 0.0558
# Epoch 47 Batch 800 Loss 0.0427
# Epoch 47 Batch 900 Loss 0.0417
# Epoch 47 Batch 1000 Loss 0.0300
# Epoch 47 Batch 1100 Loss 0.0681
# Epoch 47 Batch 1200 Loss 0.0240
# Epoch 47 Loss 0.0395
# Time taken for 1 epoch 96.85002899169922 sec
#
# Epoch 48 Batch 0 Loss 0.0251
# Epoch 48 Batch 100 Loss 0.0222
# Epoch 48 Batch 200 Loss 0.0278
# Epoch 48 Batch 300 Loss 0.0341
# Epoch 48 Batch 400 Loss 0.0319
# Epoch 48 Batch 500 Loss 0.0242
# Epoch 48 Batch 600 Loss 0.0409
# Epoch 48 Batch 700 Loss 0.0517
# Epoch 48 Batch 800 Loss 0.0388
# Epoch 48 Batch 900 Loss 0.0397
# Epoch 48 Batch 1000 Loss 0.0512
# Epoch 48 Batch 1100 Loss 0.0278
# Epoch 48 Batch 1200 Loss 0.0375
# Epoch 48 Loss 0.0391
# Time taken for 1 epoch 97.66067934036255 sec
#
# Epoch 49 Batch 0 Loss 0.0561
# Epoch 49 Batch 100 Loss 0.0386
# Epoch 49 Batch 200 Loss 0.0274
# Epoch 49 Batch 300 Loss 0.0408
# Epoch 49 Batch 400 Loss 0.0323
# Epoch 49 Batch 500 Loss 0.0355
# Epoch 49 Batch 600 Loss 0.0222
# Epoch 49 Batch 700 Loss 0.0355
# Epoch 49 Batch 800 Loss 0.0438
# Epoch 49 Batch 900 Loss 0.0397
# Epoch 49 Batch 1000 Loss 0.0733
# Epoch 49 Batch 1100 Loss 0.0541
# Epoch 49 Batch 1200 Loss 0.0410
# Epoch 49 Loss 0.0390
# Time taken for 1 epoch 96.94073390960693 sec
#
# Epoch 50 Batch 0 Loss 0.0257
# Epoch 50 Batch 100 Loss 0.0261
# Epoch 50 Batch 200 Loss 0.0203
# Epoch 50 Batch 300 Loss 0.0411
# Epoch 50 Batch 400 Loss 0.0335
# Epoch 50 Batch 500 Loss 0.0475
# Epoch 50 Batch 600 Loss 0.0413
# Epoch 50 Batch 700 Loss 0.0440
# Epoch 50 Batch 800 Loss 0.0468
# Epoch 50 Batch 900 Loss 0.0544
# Epoch 50 Batch 1000 Loss 0.0508
# Epoch 50 Batch 1100 Loss 0.0387
# Epoch 50 Batch 1200 Loss 0.0579
# Epoch 50 Loss 0.0389
# Time taken for 1 epoch 97.85848379135132 sec

# %% [markdown]
# ## Translate
#
# * The evaluate function is similar to the training loop, except we don't use *teacher forcing* here. The input to the decoder at each time step is its previous predictions along with the hidden state and the encoder output.
# * Stop predicting when the model predicts the *end token*.
# * And store the *attention weights for every time step*.
#
# Note: The encoder output is calculated only once for one input.

# %%
def evaluate(sentence):
  attention_plot = np.zeros((max_length_targ, max_length_inp))

  sentence = preprocess_sentence(sentence)

  inputs = [inp_lang.word_index[i] for i in sentence.split(' ')]
  inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs],
                                                         maxlen=max_length_inp,
                                                         padding='post')
  inputs = tf.convert_to_tensor(inputs)

  result = ''

  hidden = [tf.zeros((1, units))]
  enc_out, enc_hidden = encoder(inputs, hidden)

  dec_hidden = enc_hidden
  dec_input = tf.expand_dims([targ_lang.word_index['<start>']], 0)

  for t in range(max_length_targ):
    predictions, dec_hidden, attention_weights = decoder(dec_input,
                                                         dec_hidden,
                                                         enc_out)

    # storing the attention weights to plot later on
    attention_weights = tf.reshape(attention_weights, (-1, ))
    attention_plot[t] = attention_weights.numpy()

    predicted_id = tf.argmax(predictions[0]).numpy()

    result += targ_lang.index_word[predicted_id] + ' '

    if targ_lang.index_word[predicted_id] == '<end>':
      return result, sentence, attention_plot

    # the predicted ID is fed back into the model
    dec_input = tf.expand_dims([predicted_id], 0)

  return result, sentence, attention_plot

# %%
# function for plotting the attention weights
def plot_attention(attention, sentence, predicted_sentence):
  fig = plt.figure(figsize=(10,10))
  ax = fig.add_subplot(1, 1, 1)
  ax.matshow(attention, cmap='viridis')

  fontdict = {'fontsize': 14}

  ax.set_xticklabels([''] + sentence, fontdict=fontdict, rotation=90)
  ax.set_yticklabels([''] + predicted_sentence, fontdict=fontdict)

  ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
  ax.yaxis.set_major_locator(ticker.MultipleLocator(1))

  plt.show()

# %%
def translate(sentence):
  result, sentence, attention_plot = evaluate(sentence)

  print('Input: %s' % (sentence))
  print('Predicted translation: {}'.format(result))

  attention_plot = attention_plot[:len(result.split(' ')), :len(sentence.split(' '))]
  plot_attention(attention_plot, sentence.split(' '), result.split(' '))

# %% [markdown]
# ## Restore the latest checkpoint and test

# %%
# restoring the latest checkpoint in checkpoint_dir
checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))

# %%
translate('Здесь хорошо.')
# Out:
# Input: <start> здесь хорошо . <end>
# Predicted translation: it's nice . <end>

# %%
translate('Я не смогу поехать.')
# Out:
# Input: <start> я не смогу поехать . <end>
# Predicted translation: i can't go . <end>

# %%
translate(u'Вы еще дома?')
# Out:
# Input: <start> вы еще дома ? <end>
# Predicted translation: are you still at home ? <end>

# %%
translate(u'Вы все еще дома?')
# Out:
# Input: <start> вы все еще дома ? <end>
# Predicted translation: are you still at home ? <end>

# %%
translate(u'Попробуй сделать это.')
# Out:
# Input: <start> попробуй сделать это . <end>
# Predicted translation: try to do it . <end>

# %%
translate(u'Я не люблю, когда идет снег.')
# Out:
# Input: <start> я не люблю , когда идет снег . <end>
# Predicted translation: i don't like math . <end>

# %%
translate(u'Я никогда такого не делаю.')
# Out:
# Input: <start> я никогда такого не делаю . <end>
# Predicted translation: i never do that . <end>

# %%
translate(u'Привет, как прошла поездка в деревню?')
# Out:
# Input: <start> привет , как прошла поездка в деревню ? <end>
# Predicted translation: hi , how are you ? <end>

# %%
translate(u'Повседневная практика показывает, что новая модель организационной деятельности требует определения и уточнения существующих финансовых и административных условий?')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-47-210247d91eef> in <module>()
# ----> 1 translate(u'Повседневная практика показывает, что новая модель организационной деятельности требует определения и уточнения существующих финансовых и административных условий?')
#
# <ipython-input-31-bd54cd790ad2> in translate(sentence)
#       1 def translate(sentence):
# ----> 2   result, sentence, attention_plot = evaluate(sentence)
#       3
#       4   print('Input: %s' % (sentence))
#       5   print('Predicted translation: {}'.format(result))
#
# <ipython-input-29-88c350b1987b> in evaluate(sentence)
#       4   sentence = preprocess_sentence(sentence)
#       5
# ----> 6   inputs = [inp_lang.word_index[i] for i in sentence.split(' ')]
#       7   inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs],
#       8                                                          maxlen=max_length_inp,
#
# <ipython-input-29-88c350b1987b> in <listcomp>(.0)
#       4   sentence = preprocess_sentence(sentence)
#       5
# ----> 6   inputs = [inp_lang.word_index[i] for i in sentence.split(' ')]
#       7   inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs],
#       8                                                          maxlen=max_length_inp,
#
# KeyError: 'повседневная'

# %%
translate(u'Не следует, забывать о том, что повышение уровень сознания играет роль')
# Out:
# Input: <start> не следует , забывать о том , что повышение уровень сознания играет роль <end>
# Predicted translation: must not think i think we think we think we think

# %% [markdown]
# На множество слов выдает ошибку, так как нет в словаре. Перевод посредственный, много ошибок. Необходимо до учивать и взять более обширный словарь, но тогда значительно увеличится время обучения.
